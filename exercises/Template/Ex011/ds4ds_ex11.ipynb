# %% [markdown]
# # DS4DS Exercise Sheet 11

# %% [markdown]
# **General Instructions:**
#
# - Review the weekly course material (lectures, readings, slides, etc.) before starting the exercises.
# - Complete all assigned exercises independently before the Q&A session.
# - Please use Julia Version 1.10.x to ensure compatibility.
# - Please only write between the `#--- YOUR CODE STARTS HERE ---#` and `#--- YOUR CODE ENDS HERE ---#` comments.

# %%
# Notebook-local environment bootstrap for Julia 1.12.1 (one-stop)
# This cell activates the notebook folder as a project, installs the required packages
# and attempts to build & precompile them. Run this cell first (it may take a few minutes).
import Pkg
proj_dir = dirname(Base.current_project())
println("Ensuring project at: ", proj_dir)
try
    Pkg.activate(proj_dir)
    # Minimal package set required by the notebook (tweak if you know additional needs)
    pkgs = [
        "Printf", "DelimitedFiles", "Plots", "GZip", "StatsBase", "LaTeXStrings",
        "Serialization", "OrdinaryDiffEq", "Lux", "Random", "ComponentArrays",
        "SciMLSensitivity", "Optimization", "Zygote", "Flux"
    ]
    for p in pkgs
        try
            println("Adding package: ", p)
            Pkg.add(p)
        catch e
            @warn "Pkg.add failed for $p; continuing" exception=(e, catch_backtrace())
        end
    end
    try
        Pkg.instantiate()
        Pkg.precompile()
    catch e
        @warn "Instantiate / precompile failed (continuing)." exception=(e, catch_backtrace())
    end
catch e
    @warn "Failed to activate notebook project." exception=(e, catch_backtrace())
end
# Out:
# Ensuring project at: c:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course
# Adding package: Printf
#   Activating project at `c:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course`
#    Resolving package versions...
#    Installed MbedTLS_jll ─ v2.28.6+0
#   Installing 1 artifacts
#    Installed artifact MbedTLS               3.9 MiB
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Project.toml`
#   [de0858da] + Printf v1.11.0
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Manifest.toml`
# ⌃ [c8ffd9c3] ~ MbedTLS_jll v2.28.6+0 ⇒ v2.28.6+0
#   [ac6e5ff7] + JuliaSyntaxHighlighting v1.12.0
#   [37e2e46d] ↑ LinearAlgebra v1.11.0 ⇒ v1.12.0
#   [ca575930] ↑ NetworkOptions v1.2.0 ⇒ v1.3.0
#   [44cfe95a] ↑ Pkg v1.11.0 ⇒ v1.12.0
#   [2f01184e] ↑ SparseArrays v1.11.0 ⇒ v1.12.0
#   [e66e0078] ↑ CompilerSupportLibraries_jll v1.1.1+0 ⇒ v1.3.0+1
#   [deac9b47] ↑ LibCURL_jll v8.6.0+0 ⇒ v8.11.1+1
#   [e37daf67] ↑ LibGit2_jll v1.7.2+0 ⇒ v1.9.0+0
#   [29816b5a] ↑ LibSSH2_jll v1.11.0+1 ⇒ v1.11.3+1
#   [14a3606d] ↑ MozillaCACerts_jll v2023.12.12 ⇒ v2025.5.20
#   [4536629a] ↑ OpenBLAS_jll v0.3.27+1 ⇒ v0.3.29+0
#   [05823500] ↑ OpenLibm_jll v0.8.5+0 ⇒ v0.8.7+0
#   [458c3c95] ↓ OpenSSL_jll v3.5.4+0 ⇒ v3.5.1+0
#   [efcefdf7] ↑ PCRE2_jll v10.42.0+1 ⇒ v10.44.0+1
#   [bea87d4a] ↑ SuiteSparse_jll v7.7.0+0 ⇒ v7.8.3+2
#   [83775a58] ↑ Zlib_jll v1.2.13+1 ⇒ v1.3.1+2
#   [8e850b90] ↑ libblastrampoline_jll v5.11.0+0 ⇒ v5.15.0+0
#   [8e850ede] ↑ nghttp2_jll v1.59.0+0 ⇒ v1.64.0+1
#   [3f19e933] ↑ p7zip_jll v17.4.0+2 ⇒ v17.5.0+2
#         Info Packages marked with ⌃ have new versions available and may be upgradable.
# Precompiling packages...
#     796.2 ms  ✓ BufferedStreams
#     802.9 ms  ✓ UnsafeArrays
#     868.1 ms  ✓ VersionParsing
#     865.4 ms  ✓ MPIPreferences
#     956.6 ms  ✓ COSMOAccelerators
#    1039.5 ms  ✓ StructTypes
#    1221.2 ms  ✓ AMD
#     628.7 ms  ✓ PrecompileTools
#     928.9 ms  ✓ libsodium_jll
#     826.6 ms  ✓ Xorg_libpciaccess_jll
#     980.5 ms  ✓ libaec_jll
#    1041.3 ms  ✓ XML2_jll
#    1020.7 ms  ✓ MbedTLS_jll
#    1138.0 ms  ✓ MicrosoftMPI_jll
#     821.0 ms  ✓ CodecBzip2
#    1190.1 ms  ✓ QDLDL
#    2443.9 ms  ✓ DataStructures
#    2399.6 ms  ✓ MPItrampoline_jll
#    2530.7 ms  ✓ FFMPEG_jll
#    2110.8 ms  ✓ PreallocationTools
#    3807.4 ms  ✓ RecipesBase
#    7030.4 ms  ✓ Static
#    1751.9 ms  ✓ ZeroMQ_jll
#    3441.7 ms  ✓ Hwloc_jll
#    9100.8 ms  ✓ ColorSchemes
#   13532.6 ms  ✓ SparseMatrixColorings
#    2517.6 ms  ✓ SortingAlgorithms
#    3054.1 ms  ✓ MbedTLS
#   16382.6 ms  ✓ StaticArrays
#    2868.0 ms  ✓ FFMPEG
#    1589.6 ms  ✓ PreallocationTools → PreallocationToolsForwardDiffExt
#    1316.0 ms  ✓ BitTwiddlingConvenienceFunctions
#    2986.1 ms  ✓ GR_jll
#    5765.1 ms  ✓ RecursiveArrayTools
#    4192.9 ms  ✓ CPUSummary
#   24524.4 ms  ✓ Parsers
#    4284.5 ms  ✓ OpenMPI_jll
#    4206.2 ms  ✓ MPICH_jll
#    7923.4 ms  ✓ ZMQ
#    1878.3 ms  ✓ DifferentiationInterface → DifferentiationInterfaceSparseMatrixColoringsExt
#    2342.7 ms  ✓ SparseMatrixColorings → SparseMatrixColoringsColorsExt
#    1608.3 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#    1517.0 ms  ✓ StaticArrays → StaticArraysChainRulesCoreExt
#    6597.7 ms  ✓ StatsBase
#    1580.6 ms  ✓ DifferentiationInterface → DifferentiationInterfaceStaticArraysExt
#    1567.6 ms  ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#    1442.9 ms  ✓ Adapt → AdaptStaticArraysExt
#    1714.8 ms  ✓ StructArrays → StructArraysStaticArraysExt
#    1610.5 ms  ✓ Accessors → StaticArraysExt
#    1520.2 ms  ✓ FiniteDiff → FiniteDiffStaticArraysExt
#    3805.8 ms  ✓ FastGaussQuadrature
#    6135.6 ms  ✓ ForwardDiff → ForwardDiffStaticArraysExt
#   28887.8 ms  ✓ PlotUtils
#    5085.9 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsTablesExt
#    3719.9 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsForwardDiffExt
#   56613.8 ms  ✓ ExponentialUtilities
#    2896.7 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsStructArraysExt
#    2807.0 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsSparseArraysExt
#    2406.5 ms  ✓ PolyesterWeave
#   45187.3 ms  ✓ StaticArrayInterface
#   32169.2 ms  ✓ ArrayLayouts
#    5480.6 ms  ✓ JSON
#    7387.9 ms  ✓ HDF5_jll
#   42202.6 ms  ✓ HTTP
#    9273.3 ms  ✓ Optim
#    5773.1 ms  ✓ ExponentialUtilities → ExponentialUtilitiesStaticArraysExt
#    9247.4 ms  ✓ PlotThemes
#    4559.2 ms  ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#    3415.2 ms  ✓ CloseOpenIntervals
#    2874.0 ms  ✓ LayoutPointers
#   76772.5 ms  ✓ Zygote
#   19985.9 ms  ✓ JSON3
#   11490.8 ms  ✓ RecipesPipeline
#    2539.8 ms  ✓ Conda
#    3781.3 ms  ✓ ArrayLayouts → ArrayLayoutsSparseArraysExt
#    3901.4 ms  ✓ BenchmarkTools
#    2465.1 ms  ✓ StrideArraysCore
#    4155.8 ms  ✓ Zygote → ZygoteColorsExt
#    4108.1 ms  ✓ DifferentiationInterface → DifferentiationInterfaceZygoteExt
#   29504.4 ms  ✓ SciMLBase
#    2399.4 ms  ✓ Polyester
#    7062.1 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsZygoteExt
#    2283.0 ms  ✓ SciMLBase → SciMLBaseDifferentiationInterfaceExt
#    3162.4 ms  ✓ SciMLBase → SciMLBaseForwardDiffExt
#   12736.9 ms  ✓ GR
#    7366.7 ms  ✓ LazyArrays
#    2622.3 ms  ✓ SciMLBase → SciMLBaseChainRulesCoreExt
#    2147.2 ms  ✓ FastBroadcast
#    3935.0 ms  ✓ LazyArrays → LazyArraysStaticArraysExt
#   20182.7 ms  ✓ HDF5
#    2115.4 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsFastBroadcastExt
#    7946.3 ms  ✓ SciMLJacobianOperators
#    8047.8 ms  ✓ SciMLBase → SciMLBaseZygoteExt
#   20856.3 ms  ✓ IJulia
#    5853.5 ms  ✓ MAT
#    6998.1 ms  ✓ DiffEqBase
#    3066.2 ms  ✓ DiffEqBase → DiffEqBaseChainRulesCoreExt
#    3211.3 ms  ✓ DiffEqBase → DiffEqBaseForwardDiffExt
#    9954.1 ms  ✓ LineSearch
#    2897.3 ms  ✓ DiffEqBase → DiffEqBaseSparseArraysExt
#    2421.0 ms  ✓ LineSearch → LineSearchLineSearchesExt
#   13635.0 ms  ✓ NonlinearSolveBase
#    7177.7 ms  ✓ OrdinaryDiffEqCore
#    2927.6 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseChainRulesCoreExt
#    3383.4 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseSparseMatrixColoringsExt
#    3681.6 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseForwardDiffExt
#   21905.4 ms  ✓ LinearSolve
#    3593.0 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseSparseArraysExt
#    2642.8 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseLineSearchExt
#    2869.7 ms  ✓ OrdinaryDiffEqCore → OrdinaryDiffEqCoreEnzymeCoreExt
#    5688.7 ms  ✓ LinearSolve → LinearSolveEnzymeExt
#    5623.6 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseLinearSolveExt
#    9564.9 ms  ✓ BracketingNonlinearSolve
#    8777.3 ms  ✓ LinearSolve → LinearSolveForwardDiffExt
#   11658.6 ms  ✓ LinearSolve → LinearSolveSparseArraysExt
#    4490.2 ms  ✓ OrdinaryDiffEqFunctionMap
#    6077.6 ms  ✓ OrdinaryDiffEqLinear
#    5438.4 ms  ✓ OrdinaryDiffEqPRK
#    5564.6 ms  ✓ OrdinaryDiffEqExplicitRK
#    7140.0 ms  ✓ OrdinaryDiffEqStabilizedRK
#   17275.0 ms  ✓ NonlinearSolveSpectralMethods
#    6870.9 ms  ✓ OrdinaryDiffEqRKN
#    8047.8 ms  ✓ OrdinaryDiffEqSSPRK
#   14809.7 ms  ✓ OrdinaryDiffEqTsit5
#    5398.7 ms  ✓ OrdinaryDiffEqQPRK
#    6946.3 ms  ✓ OrdinaryDiffEqHighOrderRK
#    5865.2 ms  ✓ OrdinaryDiffEqSymplecticRK
#    2679.2 ms  ✓ BracketingNonlinearSolve → BracketingNonlinearSolveForwardDiffExt
#    6351.3 ms  ✓ OrdinaryDiffEqFeagin
#    8766.9 ms  ✓ OrdinaryDiffEqLowOrderRK
#    7809.0 ms  ✓ OrdinaryDiffEqLowStorageRK
#    2825.4 ms  ✓ NonlinearSolveSpectralMethods → NonlinearSolveSpectralMethodsForwardDiffExt
#    4359.6 ms  ✓ OrdinaryDiffEqNordsieck
#   11244.4 ms  ✓ OrdinaryDiffEqDifferentiation
#    2659.6 ms  ✓ BracketingNonlinearSolve → BracketingNonlinearSolveChainRulesCoreExt
#    7052.9 ms  ✓ OrdinaryDiffEqAdamsBashforthMoulton
#   99059.6 ms  ✓ MathOptInterface
#   11478.6 ms  ✓ OrdinaryDiffEqDifferentiation → OrdinaryDiffEqDifferentiationSparseArraysExt
#   22087.1 ms  ✓ SimpleNonlinearSolve
#   34266.9 ms  ✓ NonlinearSolveQuasiNewton
#    4527.6 ms  ✓ Optim → OptimMOIExt
#   10838.8 ms  ✓ COSMO
#   16460.3 ms  ✓ OrdinaryDiffEqExponentialRK
#    7856.9 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveChainRulesCoreExt
#   68790.9 ms  ✓ OrdinaryDiffEqVerner
#   60521.9 ms  ✓ NonlinearSolveFirstOrder
#  125405.8 ms  ✓ Plots
#    5910.9 ms  ✓ NonlinearSolveQuasiNewton → NonlinearSolveQuasiNewtonForwardDiffExt
#   21550.0 ms  ✓ OrdinaryDiffEqExtrapolation
#    4621.3 ms  ✓ Plots → IJuliaExt
#   47790.3 ms  ✓ JuMP
#   44759.3 ms  ✓ OrdinaryDiffEqRosenbrock
#   20132.4 ms  ✓ NonlinearSolve
#    4731.3 ms  ✓ OrdinaryDiffEqNonlinearSolve
#    7510.3 ms  ✓ OrdinaryDiffEqIMEXMultistep
#    7798.9 ms  ✓ OrdinaryDiffEqStabilizedIRK
#    8395.1 ms  ✓ OrdinaryDiffEqPDIRK
#    9435.4 ms  ✓ OrdinaryDiffEqSDIRK
#   14742.1 ms  ✓ OrdinaryDiffEqBDF
#   25514.8 ms  ✓ OrdinaryDiffEqFIRK
#   17108.8 ms  ✓ OrdinaryDiffEqDefault
# Adding package: DelimitedFiles
#    5719.6 ms  ✓ OrdinaryDiffEq
#   162 dependencies successfully precompiled in 299 seconds. 275 already precompiled.
#    Resolving package versions...
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Project.toml`
#   [8bb1440f] + DelimitedFiles v1.9.1
#     Manifest No packages added to or removed from `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Manifest.toml`
# Adding package: Plots
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Manifest.toml`
# Adding package: GZip
#    Resolving package versions...
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Project.toml`
#   [92fee26a] + GZip v0.6.2
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Manifest.toml`
#   [92fee26a] + GZip v0.6.2
# Adding package: StatsBase
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Manifest.toml`
# Adding package: LaTeXStrings
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Manifest.toml`
# Adding package: Serialization
#    Resolving package versions...
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Project.toml`
#   [9e88b42a] + Serialization v1.11.0
#     Manifest No packages added to or removed from `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Manifest.toml`
# Adding package: OrdinaryDiffEq
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Manifest.toml`
# Adding package: Lux
#    Resolving package versions...
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Project.toml`
# ⌃ [b2108857] + Lux v1.21.1
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Manifest.toml`
#   [dce04be8] + ArgCheck v2.5.0
#   [a9b6321e] + Atomix v1.1.2
#   [8d63f2c5] + DispatchDoctor v0.4.26
#   [d9f16b24] + Functors v0.5.2
#   [076d061b] + HashArrayMappedTries v0.2.0
#   [63c18a36] + KernelAbstractions v0.9.38
# ⌃ [b2108857] + Lux v1.21.1
#   [bb33d45b] + LuxCore v1.4.2
#   [82251201] + LuxLib v1.12.1
#   [7e8f7934] + MLDataDevices v1.14.0
#   [872c559c] + NNlib v0.9.31
#   [3bd65402] + Optimisers v0.4.6
#   [7e506255] + ScopedValues v1.5.0
#   [013be700] + UnsafeAtomics v0.3.0
#   [d49dbf32] + WeightInitializers v1.2.1
#         Info Packages marked with ⌃ have new versions available and may be upgradable.
# Precompiling packages...
#    1096.8 ms  ✓ MLDataDevices → MLDataDevicesRecursiveArrayToolsExt
#    2171.7 ms  ✓ MLDataDevices → MLDataDevicesZygoteExt
#    4495.1 ms  ✓ KernelAbstractions
#    1774.6 ms  ✓ KernelAbstractions → LinearAlgebraExt
#    1765.9 ms  ✓ KernelAbstractions → EnzymeExt
#    1868.8 ms  ✓ StructArrays → StructArraysGPUArraysCoreExt
#    1927.2 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsKernelAbstractionsExt
#    2178.5 ms  ✓ KernelAbstractions → SparseArraysExt
#    5206.2 ms  ✓ LinearSolve → LinearSolveKernelAbstractionsExt
#    6081.3 ms  ✓ NNlib
#    1538.5 ms  ✓ NNlib → NNlibForwardDiffExt
#    1630.1 ms  ✓ NNlib → NNlibSpecialFunctionsExt
#    1742.1 ms  ✓ NNlib → NNlibEnzymeCoreExt
#    4383.0 ms  ✓ LuxLib
#    9199.8 ms  ✓ Lux
# Adding package: Random
#    2661.0 ms  ✓ Lux → LuxZygoteExt
#   16 dependencies successfully precompiled in 33 seconds. 463 already precompiled.
#    Resolving package versions...
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Project.toml`
#   [9a3f8284] + Random v1.11.0
#     Manifest No packages added to or removed from `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Manifest.toml`
# Adding package: ComponentArrays
#    Resolving package versions...
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Project.toml`
#   [b0b7db55] + ComponentArrays v0.15.29
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Manifest.toml`
#   [b0b7db55] + ComponentArrays v0.15.29
# Precompiling packages...
#    1114.5 ms  ✓ ComponentArrays
#    1458.6 ms  ✓ ComponentArrays → ComponentArraysOptimisersExt
#    1548.8 ms  ✓ MLDataDevices → MLDataDevicesComponentArraysExt
#    1696.4 ms  ✓ ComponentArrays → ComponentArraysRecursiveArrayToolsExt
#    2472.7 ms  ✓ ComponentArrays → ComponentArraysSciMLBaseExt
#    2842.9 ms  ✓ Lux → LuxComponentArraysExt
#    3105.3 ms  ✓ ComponentArrays → ComponentArraysZygoteExt
# Adding package: SciMLSensitivity
#    3385.6 ms  ✓ ComponentArrays → ComponentArraysKernelAbstractionsExt
#   8 dependencies successfully precompiled in 6 seconds. 479 already precompiled.
#    Resolving package versions...
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Project.toml`
#   [1ed8b502] + SciMLSensitivity v7.90.0
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Manifest.toml`
#   [fa961155] + CEnum v0.5.0
#   [7057c7e9] + Cassette v0.3.14
#   [459566f4] + DiffEqCallbacks v4.10.1
#   [77a26b50] + DiffEqNoiseProcess v5.24.1
#   [31c24e10] + Distributions v0.25.122
#   [7da242da] + Enzyme v0.13.93
#   [f62d2435] + FunctionProperties v0.1.2
#   [61eb1bfa] + GPUCompiler v1.7.2
#   [34004b35] + HypergeometricFunctions v0.3.28
#   [929cbde3] + LLVM v9.4.4
#   [d8793406] + ObjectFile v0.5.0
#   [90014a1f] + PDMats v0.11.36
#   [e409e4f3] + PoissonRandom v0.4.7
#   [1fd47b50] + QuadGK v2.11.2
#   [74087812] + Random123 v1.7.1
#   [e6cf234a] + RandomNumbers v1.6.0
#   [ae5879a3] + ResettableStacks v1.1.1
#   [37e2e3b7] + ReverseDiff v1.16.1
#   [79098fc4] + Rmath v0.9.0
#   [1ed8b502] + SciMLSensitivity v7.90.0
#   [4c63d2b9] + StatsFuns v1.5.2
#   [53d494c1] + StructIO v0.3.1
#   [9f7883ad] + Tracker v0.2.38
#   [e689c965] + Tracy v0.1.6
#   [7cc45869] + Enzyme_jll v0.0.205+0
#   [dad2f222] + LLVMExtra_jll v0.0.38+0
#   [ad6e5548] + LibTracyClient_jll v0.9.1+6
#   [f50d1b31] + Rmath_jll v0.5.1+0
# Precompiling packages...
#    1392.0 ms  ✓ ResettableStacks
#    1925.5 ms  ✓ PDMats → StatsBaseExt
#    2676.7 ms  ✓ QuadGK
#    7422.6 ms  ✓ DiffEqCallbacks
#    9393.0 ms  ✓ Tracker
#    2647.5 ms  ✓ DiffEqCallbacks → DiffEqCallbacksFunctorsExt
#    2518.3 ms  ✓ FastPower → FastPowerTrackerExt
#    2730.5 ms  ✓ DifferentiationInterface → DifferentiationInterfaceTrackerExt
#    9723.8 ms  ✓ Distributions
#    3274.2 ms  ✓ Tracker → TrackerPDMatsExt
#    2862.9 ms  ✓ ArrayInterface → ArrayInterfaceTrackerExt
#    2945.2 ms  ✓ MLDataDevices → MLDataDevicesTrackerExt
#    2906.7 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsTrackerExt
#    3113.4 ms  ✓ ComponentArrays → ComponentArraysTrackerExt
#    3495.9 ms  ✓ SciMLBase → SciMLBaseTrackerExt
#    4385.5 ms  ✓ Zygote → ZygoteTrackerExt
#    4567.7 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseTrackerExt
#    4350.1 ms  ✓ Lux → LuxTrackerExt
#    6078.4 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveTrackerExt
#    4541.2 ms  ✓ DiffEqBase → DiffEqBaseTrackerExt
#    7428.5 ms  ✓ LuxLib → LuxLibTrackerExt
#    3356.4 ms  ✓ Distributions → DistributionsTestExt
#    2831.9 ms  ✓ Distributions → DistributionsChainRulesCoreExt
#    2388.6 ms  ✓ LuxCore → LuxCoreArrayInterfaceTrackerExt
#    3018.8 ms  ✓ SciMLBase → SciMLBaseDistributionsExt
#    4505.6 ms  ✓ DiffEqNoiseProcess
#   33405.0 ms  ✓ ReverseDiff
#    7803.8 ms  ✓ MLDataDevices → MLDataDevicesReverseDiffExt
#    8047.5 ms  ✓ DifferentiationInterface → DifferentiationInterfaceReverseDiffExt
#    7973.9 ms  ✓ PreallocationTools → PreallocationToolsReverseDiffExt
#    7890.2 ms  ✓ ArrayInterface → ArrayInterfaceReverseDiffExt
#    7844.5 ms  ✓ FastPower → FastPowerReverseDiffExt
#   15270.0 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsReverseDiffExt
#   11135.5 ms  ✓ SciMLBase → SciMLBaseReverseDiffExt
#   11383.9 ms  ✓ ComponentArrays → ComponentArraysReverseDiffExt
#   14316.4 ms  ✓ LuxLib → LuxLibReverseDiffExt
#   15153.3 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseReverseDiffExt
#   16092.9 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveReverseDiffExt
#   15066.0 ms  ✓ Lux → LuxReverseDiffExt
#   11188.8 ms  ✓ LuxCore → LuxCoreArrayInterfaceReverseDiffExt
#   14784.7 ms  ✓ DiffEqBase → DiffEqBaseReverseDiffExt
#   67495.8 ms  ✓ GPUCompiler
#   15095.2 ms  ✓ DiffEqNoiseProcess → DiffEqNoiseProcessReverseDiffExt
#   41851.2 ms  ✓ Enzyme
#    4625.7 ms  ✓ FastPower → FastPowerEnzymeExt
#    4900.0 ms  ✓ Enzyme → EnzymeLogExpFunctionsExt
#    5617.0 ms  ✓ Enzyme → EnzymeGPUArraysCoreExt
#    5822.3 ms  ✓ Enzyme → EnzymeStaticArraysExt
#    5939.4 ms  ✓ Enzyme → EnzymeChainRulesCoreExt
#    6186.6 ms  ✓ DifferentiationInterface → DifferentiationInterfaceEnzymeExt
#    7281.4 ms  ✓ Enzyme → EnzymeSpecialFunctionsExt
#    2772.4 ms  ✓ LuxLib → LuxLibEnzymeExt
#    5087.6 ms  ✓ SciMLBase → SciMLBaseEnzymeExt
#    5036.4 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseEnzymeExt
#    5179.3 ms  ✓ QuadGK → QuadGKEnzymeExt
#    4875.6 ms  ✓ DiffEqBase → DiffEqBaseEnzymeExt
#    6535.6 ms  ✓ Lux → LuxEnzymeExt
# Adding package: Optimization
#   11461.9 ms  ✓ SciMLSensitivity
#   58 dependencies successfully precompiled in 134 seconds. 509 already precompiled.
#    Resolving package versions...
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Project.toml`
#   [7f7a1694] + Optimization v5.1.0
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Manifest.toml`
#   [1520ce14] + AbstractTrees v0.4.5
#   [88cd18e8] + ConsoleProgressMonitor v0.1.2
#   [1d6d02ad] + LeftChildRightSiblingTrees v0.2.1
#   [7f7a1694] + Optimization v5.1.0
#   [bca83a33] + OptimizationBase v4.0.1
#   [33c8b6b6] + ProgressLogging v0.1.5
#   [92933f4c] + ProgressMeter v1.11.0
#   [9f842d2f] + SparseConnectivityTracer v1.1.2
#   [5d786b92] + TerminalLoggers v0.1.7
# Precompiling packages...
#    1732.6 ms  ✓ PreallocationTools → PreallocationToolsSparseConnectivityTracerExt
#    2325.1 ms  ✓ SparseConnectivityTracer → SparseConnectivityTracerNNlibExt
#    2993.8 ms  ✓ OptimizationBase
#    2770.8 ms  ✓ OptimizationBase → OptimizationMLDataDevicesExt
#    3036.3 ms  ✓ Optimization
#    3880.6 ms  ✓ OptimizationBase → OptimizationZygoteExt
#    5364.4 ms  ✓ OptimizationBase → OptimizationReverseDiffExt
# Adding package: Zygote
#    5737.9 ms  ✓ OptimizationBase → OptimizationEnzymeExt
#   8 dependencies successfully precompiled in 13 seconds. 581 already precompiled.
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Manifest.toml`
# Adding package: Flux
#    Resolving package versions...
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Project.toml`
#   [587475ba] + Flux v0.16.5
#     Updating `C:\Users\Ali Abdelwanis\Documents\Teaching\DS4DS\DS4DS_Course\Manifest.toml`
#   [198e06fe] + BangBang v0.4.6
#   [9718e550] + Baselet v0.1.1
#   [6add18c4] + ContextVariablesX v0.1.3
#   [244e2a9f] + DefineSingletons v0.1.2
#   [cc61a311] + FLoops v0.2.2
#   [b9860ae5] + FLoopsBase v0.1.1
#   [587475ba] + Flux v0.16.5
#   [22cec73e] + InitialValues v0.3.1
#   [b14d175d] + JuliaVariables v0.2.4
#   [c2834f40] + MLCore v1.0.0
#   [d8e11817] + MLStyle v0.4.17
#   [f1d291b0] + MLUtils v0.4.8
#   [128add7d] + MicroCollections v0.2.0
#   [71a1bf82] + NameResolution v0.1.5
#   [0b1bfda6] + OneHotArrays v0.2.10
#   [8162dcfd] + PrettyPrint v0.2.0
#   [605ecd9f] + ShowCases v0.1.0
#   [699a6c99] + SimpleTraits v0.9.5
#   [171d559e] + SplittablesBase v0.1.15
#   [28d57a85] + Transducers v0.4.85
# Precompiling packages...
#    1334.8 ms  ✓ BangBang → BangBangStaticArraysExt
#    2082.8 ms  ✓ SciMLBase → SciMLBaseMLStyleExt
#    2009.1 ms  ✓ OneHotArrays
#    2983.2 ms  ✓ Transducers → TransducersLazyArraysExt
#    1394.6 ms  ✓ MLDataDevices → MLDataDevicesOneHotArraysExt
#    8368.6 ms  ✓ MLUtils
#    2596.4 ms  ✓ MLDataDevices → MLDataDevicesMLUtilsExt
#    3000.0 ms  ✓ Lux → LuxMLUtilsExt
#    3195.1 ms  ✓ OptimizationBase → OptimizationMLUtilsExt
#    8087.8 ms  ✓ Flux
#    4102.9 ms  ✓ Lux → LuxFluxExt
#    5518.7 ms  ✓ Flux → FluxEnzymeExt
#   12 dependencies successfully precompiled in 29 seconds. 610 already precompiled.

# %%
using Printf
using DelimitedFiles
using Plots
using GZip
using StatsBase
using LaTeXStrings
using Serialization
using OrdinaryDiffEq
using Lux
using Random
using ComponentArrays
# SciMLSensitivity provides reverse-mode adjoint support required by Optimization + Zygote
using SciMLSensitivity
using Optimization
# We no longer depend on OptimizationFlux; training uses a Flux-based loop instead
using Zygote
using Flux
# NOTE: removed other unused / optional packages to reduce dependencies and improve compatibility with Julia 1.12.1
# Removed earlier: DataInterpolations, OptimizationOptimJL, LineSearches

# %% [markdown]
# #### **a)** Split your dataset into a training and evaluation dataset. The training dataset will be used to tune the parameters of your model and the evaluation data will be used to evaluate the generalization performance of your model. Use $u(t >= 37.5s)$ and $y(t >= 37.5s)$ for the training and $u(t < 37.5s)$ and $y(t < 37.5s)$ for the evaluation datasets. Additionally, provide the corresponding timesteps for the training and eval datasets, i.e., provide ```tsteps_training``` which contains all timesteps from the dataset with $t >= 37.5s$ and ```tsteps_eval``` which contains all timesteps with $t < 37.5s$.
#
# Implement the function below to split the dataset.

# %%
function loaddata_heating(; normalize=true)
    fh = GZip.open("heating_system.dat.gz")
    data = readdlm(fh)

    data_freq = 4
    
    data = data[1:data_freq:end, :]
    
    t = data[:, 1] / 16  # time in seconds
    u = data[:, 2]  # input: voltage driving the lamp in volt
    y = data[:, 3]  # output: temperature measurement in °C

    
    dt = 2 * data_freq / 16  # time between samples in seconds (thermic process -> high inertia)
    
    # convert to Float32 for performance
    t = Float32.(t)
    u = Float32.(u) 
    y = Float32.(y)
    
    if normalize  # optional standardization of data
        dty = fit(ZScoreTransform, y)
        dtu = fit(ZScoreTransform, u)
    
        y = StatsBase.transform(dty, y)
        u = StatsBase.transform(dtu, u);
    end
    
    tspan = (t[1], t[end])
    
    return u, y, dt, tspan, t
end
# Out:
# loaddata_heating (generic function with 1 method)

# %%
u, y, dt, tspan, tsteps = loaddata_heating();

function split_dataset(u, y, tsteps)
    """
    Creates a training and evaluation split
    
    Args:
        u: System input data
        y: System output data
        tsteps: time steps of the data trajectories

    Returns:
        u_training: u(t >= 37.5s)
        y_training: y(t >= 37.5s)
        u_eval: u(t < 37.5s)
        y_eval: y(t < 37.5s)
        tsteps_training: time steps for the training data
        tsteps_eval: time steps for the eval data
    """
    ### BEGIN SOLUTION
    
    ### END SOLUTION

    return u_training, y_training, u_eval, y_eval, tsteps_training, tsteps_eval
end
    
u_training, y_training, u_eval, y_eval, tsteps_training, tsteps_eval = split_dataset(u, y, tsteps);

# %%
u, y, dt, tspan, tsteps = loaddata_heating(normalize = false)
p = plot(tsteps, u, label=L"u", title="Simple heating system", xlabel=L"$t$ in seconds", ylabel=L"$u$ in V / $y$ in °C",
     legend=:topleft, lw=2, palette = :Set2_5)
plot!(p, tsteps, y, label=L"y", lw =2)

# %% [markdown]
# #### **b)** Implement a function for the creation of a fully-connected feed-forward neural network in dependence of the layer sizes and the activation functions. Use ```Lux.jl``` to implement it in the function template given below.

# %%
function create_ann(layer_sizes, hidden_layer_activation_function, output_activation)
    """
    Creates a neural network with the given parameters

    Args:
        layer_sizes: List of layer sizes (e.g. [5, 32, 32, 2])
        hidden_layer_activation_function: Activation function for all hidden layers (nomenclature of Lux.jl)
        output_activation: Activation function of the output layer (nomenclature of Lux.jl)

    Returns:
        ann: Resulting fully-connected neural network
    """
    ### BEGIN SOLUTION

    ### END SOLUTION

    return ann
end

# the sizes you choose here have no influence on the grading of this subtask
layer_sizes = nothing
hidden_layer_activation_function = nothing
output_activation = nothing

### BEGIN SOLUTION

### END SOLUTION
# Out:
# #19 (generic function with 1 method)

# %%
ann = create_ann(layer_sizes, hidden_layer_activation_function, output_activation)
@assert isa(ann, Lux.Chain)

### BEGIN HIDDEN TESTS
test_ann = create_ann([2, 40, 40, 1], tanh, x -> x)

@assert length(test_ann) == 3

@assert test_ann[1].in_dims == 2
@assert test_ann[1].out_dims == 40

@assert test_ann[2].in_dims == 40
@assert test_ann[2].out_dims == 40

@assert test_ann[3].in_dims == 40
@assert test_ann[3].out_dims == 1

@assert isa(test_ann.layers.layer_1.activation, Function)
@assert isa(test_ann.layers.layer_2.activation, Function)
@assert isa(test_ann.layers.layer_3.activation, Function)

### END HIDDEN TESTS

# %% [markdown]
# #### **c)** In this subtask, we want to define the NODE of the form
#
# $$
# \begin{align}
#     \frac{\mathrm{d}}{\mathrm{d}t} \hat{x}(t) &= \mathcal{M}_{\mathbf{w}} (\hat{x}(t), u(t)).
# \end{align}
# $$
#
# To this end, we need to define the ODE in the function ```dxdt(x, w, t)``` and initialize the ```training_problem```.
# Use ```create_ann``` from subtask **b)** to create a model for the ODE. If you were unable to properly implement it in **b)**, you are also allowed to create a model manually. However, you are restricted to fully-connected feed-forward neural networks. Use the variable ```w``` for the model parameters $\mathbf{w}$.
#
# The layer sizes, activation functions and initialization are set here to help you with the following subtask.
# If you want to design a different network, you are free to do so. Note, however that you might face a more complex optimization in that case.

# %%
# theoretically you would need to interpolate separately for training and evaluation, but we will look past this here
# as the time is already dividing between the two
# Use a small, dependency-free linear interpolator to avoid compatibility issues
function make_linear_interp(x, y)
    return t -> begin
        if t <= x[1]
            return y[1]
        elseif t >= x[end]
            return y[end]
        else
            i = searchsortedfirst(x, t)
            x0 = x[i-1]; x1 = x[i]
            y0 = y[i-1]; y1 = y[i]
            return y0 + (y1 - y0)*(t - x0)/(x1 - x0)
        end
    end
end
s_interp = make_linear_interp(tsteps, u)  # capture local scalar interpolator for SISO

# For this task, we have:
# - 1 state variable (the temperature)
# - 1 input variable (voltage)
# So total input size = 2
input_size = 2  # state dimension (1) + input dimension (1)
hidden_size = 8
output_size = 1
ann = create_ann([input_size, hidden_size, output_size], tanh, x -> x)

# initialize parameter and state variables
seed = 2  # This seed gives good initial state for optimization
w, st = Lux.setup(MersenneTwister(seed), ann);
w = ComponentArray(w);

### BEGIN SOLUTION
# define dxdt using a safe input construction to avoid shape mismatches

### END SOLUTION
# Out:
# ODEProblem with uType Vector{Float32} and tType Float32. In-place: false
# Non-trivial mass matrix: false
# timespan: (37.5f0, 100.0f0)
# u0: 1-element Vector{Float32}:
#  -0.9407533

# %% [markdown]
# #### **d)** Next, we want to implement the forward pass of the NODE.
#
# Implement the function below that takes the parameters of the model $\mathbf{w}$, an ODE problem, the initial state $x_0$ and the timesteps and returns the state trajectory $\hat{\mathbf{x}}_n$.
# Use the Tsit5 ODE solver, but non-adaptive.

# %%
function predict_NODE(w, problem, x0, tsteps, dt)
    """
    NODE forward pass

    Args:
        w: Parameters of the model as a ComponentArray
        problem: ODE problem
        x0: Initial state of the trajectory
        tsteps: Time steps of the trajectory
        dt: The time between two samples in the trajectory

    Returns:
        Resulting state trajectory
    
    """
    ### BEGIN SOLUTION
   
    ### END SOLUTION
end;

# %%
@assert isa(predict_NODE, Function)

### BEGIN HIDDEN TESTS

dummy_ode(x, w, t) = w * x
test_x0 = 2
test_w = 0.5

test_dt = 0.1
test_tsteps = LinRange(0, 1, 10)

trajectory = predict_NODE(
    test_w,
    ODEProblem(dummy_ode, test_x0, (test_tsteps[1], test_tsteps[end]), test_w),
    test_x0,
    test_tsteps,
    test_dt
)

println("Given trajectory: ", trajectory)

expected_trajectory = [2.0, 2.114255489520473, 2.2350381374837274, 2.362720825731292, 2.497697738003365, 2.640385576868242, 2.7912248501721817, 2.950681230981243, 3.119246995213576, 3.297442541400258]
@assert isapprox(expected_trajectory, trajectory, rtol=0, atol=1e-6)

### END HIDDEN TESTS
# Out:
# Given trajectory: [2.0, 2.1142554895490537, 2.235038137555127, 2.3627208258211767, 2.497697738076434, 2.6403855769001634, 2.7912248501628376, 2.950681230955639, 3.1192469952059936, 3.2974425414165953]

# %% [markdown]
# #### **e)** Implement the MSE loss function to compare model predictions and true trajectory. Optimize the parameters $\mathbf{w}$ of your model given in subtask c) using the given optimizer. Design an adequate optimization problem for the given template.

# %%
# Task 1 training utilities (train fresh weights on every run)
using Flux.Losses: mse
maxiters_task1 = 2_000

### BEGIN SOLUTION

end
### END SOLUTION

function train_task1!(; maxiters::Int = maxiters_task1, lr::Float64 = 1e-3, patience::Int = 15, tol::Float64 = 1e-6)
    current_w = deepcopy(w)
    best_w = deepcopy(current_w)
    best_loss = loss_NODE_task1_eval(current_w)
    no_improve = 0
    lr_val = eltype(current_w)(lr)
    for iter in 1:maxiters
        ### BEGIN SOLUTION
   
        ### END SOLUTION
        if iter % 50 == 0
            current_loss = loss_NODE_task1_eval(current_w)
            @printf("Iteration: %5d, Training loss: %.6e\n", iter, current_loss)
            if current_loss + tol < best_loss
                best_loss = current_loss
                best_w = deepcopy(current_w)
                no_improve = 0
            else
                no_improve += 1
            end
            if no_improve >= patience
                break
            end
        end
    end
    w .= best_w
    return ComponentArray(best_w)
end
# Out:
# train_task1! (generic function with 1 method)

# %% [markdown]
# After you have trained your model, continue with the evaluation below. The notebook now trains fresh weights on every run and keeps them in memory only.

# %%
# Train Task 1 model and keep weights in memory
student_w = train_task1!()
@assert student_w !== nothing
# Out:
# Iteration:    50, Training loss: 1.483160e-01
# Iteration:   100, Training loss: 1.070698e-01
# Iteration:   150, Training loss: 7.976658e-02
# Iteration:   200, Training loss: 6.654502e-02
# Iteration:   250, Training loss: 6.137136e-02
# Iteration:   300, Training loss: 5.876772e-02
# Iteration:   350, Training loss: 5.697918e-02
# Iteration:   400, Training loss: 5.550524e-02
# Iteration:   450, Training loss: 5.417984e-02
# Iteration:   500, Training loss: 5.293916e-02
# Iteration:   550, Training loss: 5.175598e-02
# Iteration:   600, Training loss: 5.061774e-02
# Iteration:   650, Training loss: 4.951827e-02
# Iteration:   700, Training loss: 4.845420e-02
# Iteration:   750, Training loss: 4.742354e-02
# Iteration:   800, Training loss: 4.642481e-02
# Iteration:   850, Training loss: 4.545699e-02
# Iteration:   900, Training loss: 4.451901e-02
# Iteration:   950, Training loss: 4.360994e-02
# Iteration:  1000, Training loss: 4.272880e-02
# Iteration:  1050, Training loss: 4.187479e-02
# Iteration:  1100, Training loss: 4.104695e-02
# Iteration:  1150, Training loss: 4.024442e-02
# Iteration:  1200, Training loss: 3.946641e-02
# Iteration:  1250, Training loss: 3.871197e-02
# Iteration:  1300, Training loss: 3.798040e-02
# Iteration:  1350, Training loss: 3.727096e-02
# Iteration:  1400, Training loss: 3.658274e-02
# Iteration:  1450, Training loss: 3.591514e-02
# Iteration:  1500, Training loss: 3.526735e-02
# Iteration:  1550, Training loss: 3.463872e-02
# Iteration:  1600, Training loss: 3.402861e-02
# Iteration:  1650, Training loss: 3.343632e-02
# Iteration:  1700, Training loss: 3.286131e-02
# Iteration:  1750, Training loss: 3.230292e-02
# Iteration:  1800, Training loss: 3.176057e-02
# Iteration:  1850, Training loss: 3.123376e-02
# Iteration:  1900, Training loss: 3.072192e-02
# Iteration:  1950, Training loss: 3.022453e-02
# Iteration:  2000, Training loss: 2.974116e-02

# %% [markdown]
# #### **f)** Evaluate the performance of your model on the evaluation dataset. To do so, define the evaluation problem.
#
# Produce a model that reaches an MSE between the prediction and the eval trajectory lower than the threshold given below.
# The previously given architecture and optimization parameters should help you reach this prediction accuracy.

# %%
x0_eval = nothing
evaluation_problem = nothing

### BEGIN SOLUTION

### END SOLUTION
# Out:
# ODEProblem with uType Vector{Float32} and tType Float32. In-place: false
# Non-trivial mass matrix: false
# timespan: (0.0f0, 37.0f0)
# u0: 1-element Vector{Float32}:
#  -0.1329399

# %%
@assert isa(x0_eval, AbstractVector)
@assert isa(evaluation_problem, ODEProblem)

prediction_eval = vec(predict_NODE(student_w, evaluation_problem, x0_eval, tsteps_eval, dt))

@assert length(prediction_eval) == length(tsteps_eval)

prediction_error_eval = Flux.mse(prediction_eval, y_eval)
println("Task 1 prediction error on eval set: ", prediction_error_eval)

@assert prediction_error_eval <= 0.3
# Out:
# Task 1 prediction error on eval set: 0.07776358

# %%
prediction_training = vec(predict_NODE(student_w, training_prob, x0, tsteps_training, dt))

p = plot(tsteps_training, y_training, label=L"y", lw =2, title="Training set performance")
plot!(p, tsteps_training, u_training, label=L"u", lw =2)
plot!(p, tsteps_training, prediction_training, label=L"\hat{y}", lw =2)

# %%
eval_plot = scatter(tsteps_eval, y_eval, label=L"$y(t)$", title="Eval performance", xlabel=L"$t$ in seconds", ylabel=L"$y$ in °C", legend=:bottomleft, lw=2)
plot!(eval_plot, tsteps_eval, prediction_eval, label=L"$\hat{y}(t)$", lw =2)

# %% [markdown]
# ## Task 2: NODE model for Lake Erie (MIMO)
#
# In this task, we once again model an underlying process using NODEs. However, the system at hand now takes multiple inputs $\mathbf{u}(t)$ and yields multiple outputs $\mathbf{y}(t)$. This means we need to model a multiple-input-multiple-output (MIMO) system.
#
# This results in the dynamics equations
#
# $$
# \begin{align}
#     \frac{\mathrm{d}}{\mathrm{d}t} \hat{\mathbf{x}}(t) &= \mathcal{M}_{\mathbf{w}} (\hat{\mathbf{x}}(t), \mathbf{u}(t)) \\
#     \hat{\mathbf{y}}(t) & = \hat{\mathbf{x}} (t).
# \end{align}
# $$
#
# The data ([source](https://ftp.esat.kuleuven.be/pub/SISTA/data/environmental/) and [description](https://ftp.esat.kuleuven.be/pub/SISTA/data/environmental/erie.txt) of the dataset) is the result of a simulation of the western basin of Lake Erie. The inputs $\mathbf{u}(t)$ are the water temperature, water conductivity, water alkalinity, the NO3 content and the total hardness of the water. The outputs $\mathbf{y}(t)$ are the amount of dissolved oxigen and the algae content. We are interested in the dynamic relationship between inputs and outputs described by the model above.

# %% [markdown]
# #### a) Below you are shown the raw output data:
#
# ![lake_erie-not_normalized](./LakeErie-NotNormalized.svg)
#
# You can see that the two outputs are scaled very differently. As a result, we need to normalize them separately.
#
# Implement the function below to normalize each output separately. Use `StatsBase.fit(ZScoreTransform, ...)` and `StatsBase.transform(...)` for the normalization.

# %%
function normalize_columnwise(data)

    ### BEGIN SOLUTION

    ### END SOLUTION
    
    return normalized_data
end

function loaddata_erie(; normalize= true)
    fh = GZip.open("erie.dat.gz")
    data = readdlm(fh)
    
    t = data[:, 1]  # time in months
    u = data[:, 2:6]
    y = data[:, 22:23]
    
    dt = 1  # time between samples in months
    
    # convert to Float32 for performance
    t = Float32.(t)
    u = Float32.(u) 
    y = Float32.(y)
    
    if normalize  # optional standardization of data
        y = normalize_columnwise(y)
        u = normalize_columnwise(u)
    end
    
    tspan = (t[1], t[end])
    
    return u, y, dt, tspan, t
end
# Out:
# loaddata_erie (generic function with 1 method)

# %% [markdown]
# Code for plot below when the data is normalized properly:
# ```
# p = plot(tsteps, y, label=L"y", title="Lake Erie", xlabel=L"$t$ in months", ylabel=L"y", legend=:topleft, background_color="#000000",lw=2, palette = :Set2_5)
# ```
#
# ![lake_erie](./LakeErie.svg)

# %%
isa(normalize_columnwise, Function)

### BEGIN HIDDEN TESTS

test_data = reduce(hcat, [LinRange(-1, 1, 10), LinRange(-5, 0, 10), LinRange(12, 4596, 10)])

normalized_data = normalize_columnwise(test_data)

expected_column = [-1.4863, -1.15601, -0.825723, -0.495434, -0.165145, 0.165145, 0.495434, 0.825723, 1.15601, 1.4863]

for idx in 1:size(normalized_data, 2)
    norm_column = normalized_data[:, idx]
    println("Given column: ", norm_column)
    @assert isapprox(norm_column, expected_column, rtol=0, atol=1e-4) 
end

### END HIDDEN TESTS
# Out:
# Given column: [-1.486301064491272, -1.156011939048767, -0.8257228136062622, -0.4954336881637573, -0.16514453291893005, 0.16514457762241364, 0.4954336881637573, 0.8257228136062622, 1.156011939048767, 1.486301064491272]
# Given column: [-1.486301064491272, -1.1560120582580566, -0.8257227540016174, -0.49543362855911255, -0.16514448821544647, 0.16514448821544647, 0.4954336881637573, 0.8257227540016174, 1.156011939048767, 1.486301064491272]
# Given column: [-1.4863009452819824, -1.156011939048767, -0.8257227540016174, -0.49543365836143494, -0.16514460742473602, 0.16514460742473602, 0.49543365836143494, 0.8257226943969727, 1.156011939048767, 1.4863009452819824]

# %% [markdown]
# #### Preparations:

# %%
u, y, dt, tspan, tsteps = loaddata_erie(normalize=true)
print(size(u))

# interpolate inputs for all channels separately using the small linear interpolator
interp_input = [make_linear_interp(tsteps, u[:, i]) for i in 1:size(u, 2)]
function interpolate_input(t)
    return [f(t) for f in interp_input]
end
# Out:
# (57, 5)
# interpolate_input (generic function with 1 method)

# %%
belonging_to_training = tsteps .<= 40
belonging_to_eval = tsteps .> 40

u_training = u[belonging_to_training, :]
y_training = y[belonging_to_training, :]
tsteps_training = tsteps[belonging_to_training, :]

u_eval = u[belonging_to_eval, :]
y_eval = y[belonging_to_eval, :]
tsteps_eval = tsteps[belonging_to_eval, :];

tsteps_training = vec(tsteps_training)
tsteps_eval = vec(tsteps_eval);

# %% [markdown]
# #### **b)** Build and train a NODE model using the training dataset. Design a feed-forward fully-connected neural network as the model.

# %%
### BEGIN SOLUTION

### END SOLUTION
# Out:
# train_task2! (generic function with 1 method)

# %% [markdown]
# After you have trained your model, proceed with the evaluation cells. The training routine runs each time the notebook is executed and does not write model parameters to disk.

# %% [markdown]
# #### **c)** Evaluate the performance of your model on the evaluation dataset. To do so, define the evaluation problem.
#
# Produce a model that reaches an MSE between the prediction and the eval trajectory lower than the threshold given below. Design a model architecture and optimization routine in the previous subtasks that reaches this level of accuracy.

# %%
# Train Task 2 model and keep weights in memory
student_w = train_task2!()
@assert student_w !== nothing
# Out:
# Iteration:    50, Training loss: 1.773960e+00
# Iteration:   100, Training loss: 1.340572e+00
# Iteration:   150, Training loss: 1.074030e+00
# Iteration:   200, Training loss: 8.971817e-01

# %%
x0_eval_task2 = nothing
evaluation_prob_task2 = nothing

### BEGIN SOLUTION

### END SOLUTION
# Out:
# ODEProblem with uType Vector{Float64} and tType Float32. In-place: false
# Non-trivial mass matrix: false
# timespan: (41.0f0, 57.0f0)
# u0: 2-element Vector{Float64}:
#  -1.3331990242004395
#   0.5546457171440125

# %%
#public test
@assert isa(x0_eval_task2, AbstractArray)
@assert isa(evaluation_prob_task2, ODEProblem)

prediction_eval_task2 = transpose(predict_NODE(student_w, evaluation_prob_task2, x0_eval_task2, tsteps_eval, dt))

@assert size(prediction_eval_task2, 1) == size(y_eval, 1)

prediction_error_eval_task2 = Flux.mse(prediction_eval_task2, y_eval)
println("Task 2 prediction error on eval set: ", prediction_error_eval_task2)

# %%
prediction_training_task2 = transpose(predict_NODE(student_w, training_prob_task2, x0_task2, tsteps_training, dt))

p = plot(tsteps_training, y_training, label=L"y", title="Lake Erie", xlabel=L"$t$ in months", ylabel=L"y", legend=:topleft,lw=2, palette = :Set2_5)
# plot!(p, tsteps_training, u_training, label=L"u", lw =2)
plot!(p, tsteps_training, prediction_training_task2, label=L"\hat{y}", lw =2)
# Out:
# Task 2 prediction error on eval set: 1.3261325927577357

# %%
prediction_eval_task2, prediction_error_eval_task2 = evaluate_result(student_w, y_eval, tsteps_eval)
eval_plot = Plots.plot(tsteps_eval, y_eval, label=L"$y(t)$", title="Lake Erie eval", xlabel=L"$t$ in months", ylabel=L"y", legend=:bottomleft,lw=2, palette = :Set2_5)
Plots.plot!(eval_plot, tsteps_eval, prediction_eval_task2, label=L"$\hat{y}(t)$", lw =2)
display(eval_plot)
# Out:
# Task 2 eval MSE: 1.3261325927577357
